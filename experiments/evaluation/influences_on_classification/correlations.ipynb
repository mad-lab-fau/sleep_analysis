# %%
import numpy as np
import pandas as pd

from pathlib import Path
import matplotlib.pyplot as plt
import seaborn as sns
from biopsykit.utils.dataframe_handling import multi_xs
import optuna

from biopsykit.stats import StatsPipeline
import pingouin as pg
import biopsykit as bp

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from fau_colors import register_cmaps
register_cmaps()

sns.set_theme(context="talk", style="white", palette="faculties", font_scale=1.2)

# %matplotlib widget

# %% [markdown]
# # Correlations to subject informations

# %%
df = pd.read_pickle("../full_df.pkl")
df = df.rename(index={"ACT + HRV + EDR":"ACT + HRV + ED-RRV"})

# %%
algorithm = "LSTM"
metric = "accuracy"
stage = "5stage"
modality_list = ["ACT", "ACT + HRV", "ACT + HRV + RRV", "ACT + HRV + ED-RRV"]

# %% [markdown]
# # Method to get regression plots

# %%
def get_regression_table(df, metric, algorithm, stage):
    df = multi_xs(df, [metric], level="metric")
    df = multi_xs(df, [algorithm], level="algorithm")
    df = multi_xs(df, [stage], level="stage")
    
    
    df = df[["data", characteristic]].astype(float)
    df_reg_result= df.groupby(["algorithm", "modality", "metric", "stage"]).apply(
        lambda df: pg.linear_regression(X=df[characteristic], y=df["data"])
    )
    df_reg_result = df_reg_result.set_index("names", append=True)
    df_reg_result = df_reg_result.round(3)
    df_reg_result = df_reg_result.xs(characteristic, level="names").sort_values(by="r2", ascending=False).sort_index()
    df_reg_result.sort_index()
    
    return df, df_reg_result.sort_index()

# %%
def get_regression_plot(df, df_reg_result, algorithm, characteristic, characteristic_title):
    algorithm_list = [algorithm]
    df_reg_2 = df_reg_result["r2"]
    df_p = df_reg_result["pval"]
    for alg in algorithm_list:
        fig, ax = plt.subplots(ncols=4, figsize=(25, 7), sharey=True)
        for i, (modality, r2, p) in enumerate(zip(modality_list, df_reg_2, df_p)):

            df_corr = multi_xs(df, [alg], level="algorithm")
            df_corr = multi_xs(df_corr, [modality], level="modality")
            df_corr = multi_xs(df_corr, [stage], level="stage")
            df_corr["data"] = df_corr["data"]
            df_corr[characteristic] = df_corr[characteristic].astype(float)
            df_corr["data"] = df_corr["data"].astype(float)
            df_corr[["data", characteristic]]
            sns.regplot(
                data=df_corr[["data", characteristic]].reset_index(), x=characteristic, y="data", ax=ax[i], line_kws={"color": "#228848"}
            )
            ax[i].set_title(modality + "  r\u00b2 = " + str(r2) + ", p = " + str(p))
            ax[i].set_ylabel("Accuracy [%]")
            ax[i].set_xlabel(characteristic_title)
            ax[i].yaxis.set_tick_params(labelbottom=True)

    plt.tight_layout()
    return fig, ax

# %% [markdown]
# # Method to get statstical boxplots for characteristics

# %%
def bin_characteristic(df, characteristic, cutoff, labels = ["bad", "good"]):    
    df["bin_" + characteristic] = pd.cut(
    df[characteristic],
    [df[characteristic].min(), cutoff, df[characteristic].max()],
    right=True,
    include_lowest=True,
    labels=labels
                 )
    return df

# %%
def calculate_stats(df, characteristic):
    df = multi_xs(df, [metric], level="metric")
    df = multi_xs(df, [algorithm], level="algorithm")
    df = multi_xs(df, [stage], level="stage")

    dict_stats = {}

    for modality in modality_list:
        steps = [
            # ("prep", "normality"),
            ("test", "pairwise_tests")
        ]

        params = {
            "dv": "data",
            "between": characteristic,
            "groupby": ["algorithm", "modality", "metric", "stage"],
            "parametric": False,
            "multicomp": {"levels": ["algorithm", "modality"]},
        }

        df_slice = multi_xs(df, [modality], level="modality")
        pipeline = StatsPipeline(steps, params, round=4)
        pipeline.apply(df_slice)

        dict_stats[modality] = pipeline

    return pipeline, dict_stats

# %%
def plot_stats(df, dict_stats, characteristic):
    df = multi_xs(df, [metric], level="metric")
    df = multi_xs(df, [algorithm], level="algorithm")
    df = multi_xs(df, [stage], level="stage")
    
    dict_brackets = {
    key: dict_stats[key].sig_brackets("test",stats_type="between", stats_effect_type="between", plot_type="multi", x="algorithm")
    for key in modality_list
    }
        
    box_pairs = {key: val[0] for key, val in dict_brackets.items()}
    pvalues = {key: val[1] for key, val in dict_brackets.items()}
    
    display(box_pairs)
    display(pvalues)
    
    fig, ax = plt.subplots(figsize=(20, 6), ncols=4)

    features = ["ACT", "ACT + HRV", "ACT + HRV + RRV", "ACT + HRV + ED-RRV"]

    
    fig, ax = bp.plotting.multi_feature_boxplot(
        data=df,
        x="algorithm",
        y="data",
        hue=characteristic,
        group="modality",
        features=features,
        stats_kwargs={
            "box_pairs": box_pairs,
            "pvalues": pvalues,
            "fontsize": "medium",
            "text_offset": -6,
            "verbose": True,
        },
        ylabels={"ACT": "Accuracy [%]", "ACT + HRV": "Accuracy [%]", "ACT + HRV + RRV": "Accuracy [%]", "ACT + HRV + ED-RRV": "Accuracy [%]"},
        axs=ax,
    )
    fig.tight_layout(rect=(0, 0, 0.91, 1), pad=3)
    handles, labels = ax[0].get_legend_handles_labels()

    for a, modality in zip(ax, features):
        a.legend().remove()
        a.set_xlabel("Algorithm")
        a.set_title(modality)
        a.yaxis.set_tick_params(labelbottom=True)

    fig.legends[0].set_title(characteristic)
    
    return fig, ax

# %%
def kruskal_stats(df, characteristic):
    df = multi_xs(df, [metric], level="metric")
    df = multi_xs(df, [algorithm], level="algorithm")
    df = multi_xs(df, [stage], level="stage")
    
    steps = [
    # ("prep", "normality"),
    ("test", "kruskal"),
    ("posthoc", "pairwise_tests"),
]

    params = {
        "dv": "data",
        "between": characteristic,
        "parametric": False,
        "groupby": ["modality", "algorithm", "metric"],
        "multicomp": {"levels": ["modality", "algorithm"]},
    }


    pipeline = StatsPipeline(steps, params, round=4)
    pipeline.apply(df);
    
    return pipeline

# %% [markdown]
# # Age

# %%
characteristic = "age"

# %%
df_, reg_result = get_regression_table(df, metric, algorithm, stage)
reg_result
# Out:
#                                                  coef     se      T   pval  \
# algorithm modality           metric   stage
# LSTM      ACT                accuracy 5stage 1  0.046  0.079  0.583  0.561
#           ACT + HRV          accuracy 5stage 1 -0.096  0.081 -1.196  0.233
#           ACT + HRV + ED-RRV accuracy 5stage 1 -0.074  0.080 -0.925  0.356
#           ACT + HRV + RRV    accuracy 5stage 1 -0.046  0.072 -0.638  0.524
#
#                                                    r2  adj_r2  CI[2.5%]  \
# algorithm modality           metric   stage
# LSTM      ACT                accuracy 5stage 1  0.002  -0.003    -0.110
#           ACT + HRV          accuracy 5stage 1  0.006   0.002    -0.255
#           ACT + HRV + ED-RRV accuracy 5stage 1  0.004  -0.001    -0.231
#           ACT + HRV + RRV    accuracy 5stage 1  0.002  -0.003    -0.189
#
#                                                 CI[97.5%]
# algorithm modality           metric   stage
# LSTM      ACT                accuracy 5stage 1      0.203
#           ACT + HRV          accuracy 5stage 1      0.062
#           ACT + HRV + ED-RRV accuracy 5stage 1      0.084
#           ACT + HRV + RRV    accuracy 5stage 1      0.096

# %%
plt.close("all")
fig, ax = get_regression_plot(df_, reg_result, algorithm, characteristic, characteristic_title="Age")
plt.savefig("Regression_to_age.pdf", format="pdf", bbox_inches="tight")
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# # AHI

# %%
characteristic = "AH-Index"

# %%
df_, reg_result = get_regression_table(df, metric, algorithm, stage)
reg_result
# Out:
#                                                  coef     se      T   pval  \
# algorithm modality           metric   stage
# LSTM      ACT                accuracy 5stage 1 -0.080  0.043 -1.877  0.062
#           ACT + HRV          accuracy 5stage 1 -0.136  0.043 -3.186  0.002
#           ACT + HRV + ED-RRV accuracy 5stage 1 -0.113  0.043 -2.655  0.009
#           ACT + HRV + RRV    accuracy 5stage 1 -0.128  0.038 -3.367  0.001
#
#                                                    r2  adj_r2  CI[2.5%]  \
# algorithm modality           metric   stage
# LSTM      ACT                accuracy 5stage 1  0.016   0.011    -0.164
#           ACT + HRV          accuracy 5stage 1  0.044   0.039    -0.220
#           ACT + HRV + ED-RRV accuracy 5stage 1  0.031   0.026    -0.197
#           ACT + HRV + RRV    accuracy 5stage 1  0.049   0.044    -0.204
#
#                                                 CI[97.5%]
# algorithm modality           metric   stage
# LSTM      ACT                accuracy 5stage 1      0.004
#           ACT + HRV          accuracy 5stage 1     -0.052
#           ACT + HRV + ED-RRV accuracy 5stage 1     -0.029
#           ACT + HRV + RRV    accuracy 5stage 1     -0.053

# %%
plt.close("all")
fig, ax = get_regression_plot(df_, reg_result, algorithm, characteristic, characteristic_title="AH-Index")
plt.savefig("Regression_to_AHI.pdf", format="pdf", bbox_inches="tight")
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# # WHIIRS_score

# %%
characteristic = "WHIIRS_score"

# %%
df_, reg_result = get_regression_table(df, metric, algorithm, stage)
reg_result
# Out:
#                                                  coef     se      T   pval  \
# algorithm modality           metric   stage
# LSTM      ACT                accuracy 5stage 1 -0.047  0.151 -0.310  0.757
#           ACT + HRV          accuracy 5stage 1 -0.141  0.153 -0.917  0.360
#           ACT + HRV + ED-RRV accuracy 5stage 1 -0.091  0.152 -0.597  0.551
#           ACT + HRV + RRV    accuracy 5stage 1 -0.135  0.137 -0.980  0.328
#
#                                                    r2  adj_r2  CI[2.5%]  \
# algorithm modality           metric   stage
# LSTM      ACT                accuracy 5stage 1  0.000  -0.004    -0.345
#           ACT + HRV          accuracy 5stage 1  0.004  -0.001    -0.443
#           ACT + HRV + ED-RRV accuracy 5stage 1  0.002  -0.003    -0.390
#           ACT + HRV + RRV    accuracy 5stage 1  0.004  -0.000    -0.405
#
#                                                 CI[97.5%]
# algorithm modality           metric   stage
# LSTM      ACT                accuracy 5stage 1      0.251
#           ACT + HRV          accuracy 5stage 1      0.162
#           ACT + HRV + ED-RRV accuracy 5stage 1      0.209
#           ACT + HRV + RRV    accuracy 5stage 1      0.136

# %%
get_regression_plot(df_, reg_result, algorithm, characteristic, characteristic_title="WHIIRS_score")
# Out:
# (<Figure size 2500x700 with 4 Axes>,
#  array([<Axes: title={'center': 'ACT  r² = 0.0, p = 0.757'}, xlabel='WHIIRS_score', ylabel='Accuracy [%]'>,
#         <Axes: title={'center': 'ACT + HRV  r² = 0.004, p = 0.36'}, xlabel='WHIIRS_score', ylabel='Accuracy [%]'>,
#         <Axes: title={'center': 'ACT + HRV + RRV  r² = 0.002, p = 0.551'}, xlabel='WHIIRS_score', ylabel='Accuracy [%]'>,
#         <Axes: title={'center': 'ACT + HRV + ED-RRV  r² = 0.004, p = 0.328'}, xlabel='WHIIRS_score', ylabel='Accuracy [%]'>],
#        dtype=object))
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# # Recording Quality

# %%
characteristic = "PSG_quality"

# %%
df_recording_qual = bin_characteristic(df, characteristic, 5)

# %%
pipeline, dict_stats = calculate_stats(df_recording_qual, "bin_" + characteristic)

# %%
fig, axs = plot_stats(df_recording_qual, dict_stats, "bin_"+characteristic)
fig.legends[0].set_title("PSG Quality")
plt.savefig("recording_quality_psg.pdf", format="pdf", bbox_inches="tight")
# Out:
# {'ACT': [], 'ACT + HRV': [], 'ACT + HRV + RRV': [], 'ACT + HRV + ED-RRV': []}
# {'ACT': [], 'ACT + HRV': [], 'ACT + HRV + RRV': [], 'ACT + HRV + ED-RRV': []}
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# # Healthy vs. Sick in general

# %%
df["sick"] = df[["sleep_apnea", "insomnia", "resstles_legs"]].sum(axis=1)
df["sick"] = pd.cut(
    df["sick"], [0, 0.1, 1], include_lowest=True, right=True, labels=["healthy", "sick"]
)

# %%
df
# Out:
#                                                                                        data  \
# algorithm type algorithm modality        stage  subject metric
# DL             LSTM      ACT             3stage 0027    accuracy                  73.951049
#                                                         bed_interval_end        1131.000000
#                                                         bed_interval_start        99.000000
#                                                         f1                        65.924768
#                                                         getup_latency              0.000000
# ...                                                                                     ...
# ML             XGBoost   ACT + HRV + RRV Binary 6807    sleep_onset_latency        5.000000
#                                                         specificity               94.650206
#                                                         total_sleep_duration    1004.000000
#                                                         wake_after_sleep_onset   447.000000
#                                                         wake_onset               982.000000
#
#                                                                                     race  \
# algorithm type algorithm modality        stage  subject metric
# DL             LSTM      ACT             3stage 0027    accuracy                   White
#                                                         bed_interval_end           White
#                                                         bed_interval_start         White
#                                                         f1                         White
#                                                         getup_latency              White
# ...                                                                                  ...
# ML             XGBoost   ACT + HRV + RRV Binary 6807    sleep_onset_latency     Hispanic
#                                                         specificity             Hispanic
#                                                         total_sleep_duration    Hispanic
#                                                         wake_after_sleep_onset  Hispanic
#                                                         wake_onset              Hispanic
#
#                                                                                 gender  \
# algorithm type algorithm modality        stage  subject metric
# DL             LSTM      ACT             3stage 0027    accuracy                female
#                                                         bed_interval_end        female
#                                                         bed_interval_start      female
#                                                         f1                      female
#                                                         getup_latency           female
# ...                                                                                ...
# ML             XGBoost   ACT + HRV + RRV Binary 6807    sleep_onset_latency       male
#                                                         specificity               male
#                                                         total_sleep_duration      male
#                                                         wake_after_sleep_onset    male
#                                                         wake_onset                male
#
#                                                                                 PSG_quality  \
# algorithm type algorithm modality        stage  subject metric
# DL             LSTM      ACT             3stage 0027    accuracy                        6.0
#                                                         bed_interval_end                6.0
#                                                         bed_interval_start              6.0
#                                                         f1                              6.0
#                                                         getup_latency                   6.0
# ...                                                                                     ...
# ML             XGBoost   ACT + HRV + RRV Binary 6807    sleep_onset_latency             7.0
#                                                         specificity                     7.0
#                                                         total_sleep_duration            7.0
#                                                         wake_after_sleep_onset          7.0
#                                                         wake_onset                      7.0
#
#                                                                                 WHIIRS_score  \
# algorithm type algorithm modality        stage  subject metric
# DL             LSTM      ACT             3stage 0027    accuracy                        15.0
#                                                         bed_interval_end                15.0
#                                                         bed_interval_start              15.0
#                                                         f1                              15.0
#                                                         getup_latency                   15.0
# ...                                                                                      ...
# ML             XGBoost   ACT + HRV + RRV Binary 6807    sleep_onset_latency             12.0
#                                                         specificity                     12.0
#                                                         total_sleep_duration            12.0
#                                                         wake_after_sleep_onset          12.0
#                                                         wake_onset                      12.0
#
#                                                                                 sleep_apnea  \
# algorithm type algorithm modality        stage  subject metric
# DL             LSTM      ACT             3stage 0027    accuracy                        0.0
#                                                         bed_interval_end                0.0
#                                                         bed_interval_start              0.0
#                                                         f1                              0.0
#                                                         getup_latency                   0.0
# ...                                                                                     ...
# ML             XGBoost   ACT + HRV + RRV Binary 6807    sleep_onset_latency             1.0
#                                                         specificity                     1.0
#                                                         total_sleep_duration            1.0
#                                                         wake_after_sleep_onset          1.0
#                                                         wake_onset                      1.0
#
#                                                                                 insomnia  \
# algorithm type algorithm modality        stage  subject metric
# DL             LSTM      ACT             3stage 0027    accuracy                     0.0
#                                                         bed_interval_end             0.0
#                                                         bed_interval_start           0.0
#                                                         f1                           0.0
#                                                         getup_latency                0.0
# ...                                                                                  ...
# ML             XGBoost   ACT + HRV + RRV Binary 6807    sleep_onset_latency          0.0
#                                                         specificity                  0.0
#                                                         total_sleep_duration         0.0
#                                                         wake_after_sleep_onset       0.0
#                                                         wake_onset                   0.0
#
#                                                                                 resstles_legs  \
# algorithm type algorithm modality        stage  subject metric
# DL             LSTM      ACT             3stage 0027    accuracy                          0.0
#                                                         bed_interval_end                  0.0
#                                                         bed_interval_start                0.0
#                                                         f1                                0.0
#                                                         getup_latency                     0.0
# ...                                                                                       ...
# ML             XGBoost   ACT + HRV + RRV Binary 6807    sleep_onset_latency               0.0
#                                                         specificity                       0.0
#                                                         total_sleep_duration              0.0
#                                                         wake_after_sleep_onset            0.0
#                                                         wake_onset                        0.0
#
#                                                                                  age  \
# algorithm type algorithm modality        stage  subject metric
# DL             LSTM      ACT             3stage 0027    accuracy                72.0
#                                                         bed_interval_end        72.0
#                                                         bed_interval_start      72.0
#                                                         f1                      72.0
#                                                         getup_latency           72.0
# ...                                                                              ...
# ML             XGBoost   ACT + HRV + RRV Binary 6807    sleep_onset_latency     60.0
#                                                         specificity             60.0
#                                                         total_sleep_duration    60.0
#                                                         wake_after_sleep_onset  60.0
#                                                         wake_onset              60.0
#
#                                                                                  AH-Index  \
# algorithm type algorithm modality        stage  subject metric
# DL             LSTM      ACT             3stage 0027    accuracy                 5.365854
#                                                         bed_interval_end         5.365854
#                                                         bed_interval_start       5.365854
#                                                         f1                       5.365854
#                                                         getup_latency            5.365854
# ...                                                                                   ...
# ML             XGBoost   ACT + HRV + RRV Binary 6807    sleep_onset_latency     43.417085
#                                                         specificity             43.417085
#                                                         total_sleep_duration    43.417085
#                                                         wake_after_sleep_onset  43.417085
#                                                         wake_onset              43.417085
#
#                                                                                 extra_work_hours  \
# algorithm type algorithm modality        stage  subject metric
# DL             LSTM      ACT             3stage 0027    accuracy                             0.0
#                                                         bed_interval_end                     0.0
#                                                         bed_interval_start                   0.0
#                                                         f1                                   0.0
#                                                         getup_latency                        0.0
# ...                                                                                          ...
# ML             XGBoost   ACT + HRV + RRV Binary 6807    sleep_onset_latency                  0.0
#                                                         specificity                          0.0
#                                                         total_sleep_duration                 0.0
#                                                         wake_after_sleep_onset               0.0
#                                                         wake_onset                           0.0
#
#                                                                                bin_PSG_quality  \
# algorithm type algorithm modality        stage  subject metric
# DL             LSTM      ACT             3stage 0027    accuracy                          good
#                                                         bed_interval_end                  good
#                                                         bed_interval_start                good
#                                                         f1                                good
#                                                         getup_latency                     good
# ...                                                                                        ...
# ML             XGBoost   ACT + HRV + RRV Binary 6807    sleep_onset_latency               good
#                                                         specificity                       good
#                                                         total_sleep_duration              good
#                                                         wake_after_sleep_onset            good
#                                                         wake_onset                        good
#
#                                                                                    sick
# algorithm type algorithm modality        stage  subject metric
# DL             LSTM      ACT             3stage 0027    accuracy                healthy
#                                                         bed_interval_end        healthy
#                                                         bed_interval_start      healthy
#                                                         f1                      healthy
#                                                         getup_latency           healthy
# ...                                                                                 ...
# ML             XGBoost   ACT + HRV + RRV Binary 6807    sleep_onset_latency        sick
#                                                         specificity                sick
#                                                         total_sleep_duration       sick
#                                                         wake_after_sleep_onset     sick
#                                                         wake_onset                 sick
#
# [319872 rows x 13 columns]

# %%
characteristic = "sick"

# %%
pipeline, dict_stats = calculate_stats(df, characteristic)

# %%
plot_stats(df_recording_qual, dict_stats, characteristic)
# Out:
# {'ACT': [], 'ACT + HRV': [], 'ACT + HRV + RRV': [], 'ACT + HRV + ED-RRV': []}
# {'ACT': [], 'ACT + HRV': [], 'ACT + HRV + RRV': [], 'ACT + HRV + ED-RRV': []}
# (<Figure size 2000x600 with 4 Axes>,
#  array([<Axes: title={'center': 'ACT'}, xlabel='Algorithm', ylabel='Accuracy [%]'>,
#         <Axes: title={'center': 'ACT + HRV'}, xlabel='Algorithm', ylabel='Accuracy [%]'>,
#         <Axes: title={'center': 'ACT + HRV + RRV'}, xlabel='Algorithm', ylabel='Accuracy [%]'>,
#         <Axes: title={'center': 'ACT + HRV + ED-RRV'}, xlabel='Algorithm', ylabel='Accuracy [%]'>],
#        dtype=object))
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# # Gender

# %%
characteristic = "gender"

# %%
pipeline, dict_stats = calculate_stats(df, characteristic)

# %%
fig, ax = plot_stats(df_recording_qual, dict_stats, characteristic)
fig.legends[0].set_title("Gender")
plt.savefig("gender_statistics.pdf", format="pdf", bbox_inches="tight")
# Out:
# {'ACT': [], 'ACT + HRV': [], 'ACT + HRV + RRV': [], 'ACT + HRV + ED-RRV': []}
# {'ACT': [], 'ACT + HRV': [], 'ACT + HRV + RRV': [], 'ACT + HRV + ED-RRV': []}
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# # Sleep Apnea

# %%
df["sleep_apnea"].replace(to_replace=[0.0, 1.0], value=["healthy", "sick"], inplace=True)
df["insomnia"].replace(to_replace=[0.0, 1.0], value=["healthy", "sick"], inplace=True)
df["resstles_legs"].replace(to_replace=[0.0, 1.0], value=["healthy", "sick"], inplace=True)

# %%
characteristic = "sleep_apnea"

# %%
pipeline, dict_stats = calculate_stats(df, characteristic)

# %%
fig, ax = plot_stats(df_recording_qual, dict_stats, characteristic)
fig.legends[0].set_title("Sleep Apnea")
plt.savefig("sleep_apnea_statistics.pdf", format="pdf", bbox_inches="tight")
# Out:
# {'ACT': [], 'ACT + HRV': [], 'ACT + HRV + RRV': [], 'ACT + HRV + ED-RRV': []}
# {'ACT': [], 'ACT + HRV': [], 'ACT + HRV + RRV': [], 'ACT + HRV + ED-RRV': []}
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# # Insomnia

# %%
characteristic = "insomnia"

# %%
pipeline, dict_stats = calculate_stats(df, characteristic)

# %%
fig, ax = plot_stats(df_recording_qual, dict_stats, characteristic)
fig.legends[0].set_title("Insomnia")
plt.savefig("Insomnia_statistics.pdf", format="pdf", bbox_inches="tight")
# Out:
# {'ACT': [], 'ACT + HRV': [], 'ACT + HRV + RRV': [], 'ACT + HRV + ED-RRV': []}
# {'ACT': [], 'ACT + HRV': [], 'ACT + HRV + RRV': [], 'ACT + HRV + ED-RRV': []}
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# # Resstles Legs

# %%
characteristic = "resstles_legs"

# %%
pipeline, dict_stats = calculate_stats(df, characteristic)

# %%
fig, ax = plot_stats(df_recording_qual, dict_stats, characteristic)
fig.legends[0].set_title("RLS")
plt.savefig("rls_statistics.pdf", format="pdf", bbox_inches="tight")
# Out:
# {'ACT': [],
#  'ACT + HRV': [(('LSTM', 'healthy'), ('LSTM', 'sick'))],
#  'ACT + HRV + RRV': [(('LSTM', 'healthy'), ('LSTM', 'sick'))],
#  'ACT + HRV + ED-RRV': [(('LSTM', 'healthy'), ('LSTM', 'sick'))]}
# {'ACT': [],
#  'ACT + HRV': [0.02013236701093903],
#  'ACT + HRV + RRV': [0.0282300589659416],
#  'ACT + HRV + ED-RRV': [0.019603253179267175]}
# p-value annotation legend:
# *: 1.00e-02 < p <= 5.00e-02
# **: 1.00e-03 < p <= 1.00e-02
# ***: p <= 1.00e-03
#
# LSTM_healthy v.s. LSTM_sick: Custom statistical test, P_val:2.013e-02
# LSTM_healthy v.s. LSTM_sick: Custom statistical test, P_val:2.823e-02
# LSTM_healthy v.s. LSTM_sick: Custom statistical test, P_val:1.960e-02
# p-value annotation legend:
# *: 1.00e-02 < p <= 5.00e-02
# **: 1.00e-03 < p <= 1.00e-02
# ***: p <= 1.00e-03
#
# LSTM_healthy v.s. LSTM_sick: Custom statistical test, P_val:2.013e-02
# LSTM_healthy v.s. LSTM_sick: Custom statistical test, P_val:2.823e-02
# LSTM_healthy v.s. LSTM_sick: Custom statistical test, P_val:1.960e-02
# p-value annotation legend:
# *: 1.00e-02 < p <= 5.00e-02
# **: 1.00e-03 < p <= 1.00e-02
# ***: p <= 1.00e-03
#
# LSTM_healthy v.s. LSTM_sick: Custom statistical test, P_val:2.823e-02
# p-value annotation legend:
# *: 1.00e-02 < p <= 5.00e-02
# **: 1.00e-03 < p <= 1.00e-02
# ***: p <= 1.00e-03
#
# LSTM_healthy v.s. LSTM_sick: Custom statistical test, P_val:1.960e-02
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# # WHIIRS (Insomnia 2)

# %%
characteristic = "WHIIRS_score"

# %%
df_whirrs = bin_characteristic(df, characteristic, 8.9)

# %%
pipeline, dict_stats = calculate_stats(df_recording_qual, "bin_" + characteristic)

# %%
plot_stats(df_recording_qual, dict_stats, "bin_"+characteristic)
# Out:
# {'ACT': [], 'ACT + HRV': [], 'ACT + HRV + RRV': [], 'ACT + HRV + ED-RRV': []}
# {'ACT': [], 'ACT + HRV': [], 'ACT + HRV + RRV': [], 'ACT + HRV + ED-RRV': []}
# (<Figure size 2000x600 with 4 Axes>,
#  array([<Axes: title={'center': 'ACT'}, xlabel='Algorithm', ylabel='Accuracy [%]'>,
#         <Axes: title={'center': 'ACT + HRV'}, xlabel='Algorithm', ylabel='Accuracy [%]'>,
#         <Axes: title={'center': 'ACT + HRV + RRV'}, xlabel='Algorithm', ylabel='Accuracy [%]'>,
#         <Axes: title={'center': 'ACT + HRV + ED-RRV'}, xlabel='Algorithm', ylabel='Accuracy [%]'>],
#        dtype=object))
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# # Race

# %%
characteristic = "race"

# %%
pipeline = kruskal_stats(df, characteristic)
pipeline.display_results()
# Out:
# <font size="3"><b> Overview </b></font>
#              dv between parametric                              groupby  \
# parameter  data    race      False  ['modality', 'algorithm', 'metric']
#
#                                        multicomp
# parameter  {'levels': ['modality', 'algorithm']}
#               test         posthoc
# parameter  kruskal  pairwise_tests
# <font size="3"><b> Statistical Tests </b></font>
# **Kruskal-Wallis H-test for independent samples**
#                                               Source  ddof1       H   p-unc
# modality           algorithm metric
# ACT                LSTM      accuracy Kruskal   race      3  4.4444  0.2173
# ACT + HRV          LSTM      accuracy Kruskal   race      3  0.1656  0.9829
# ACT + HRV + ED-RRV LSTM      accuracy Kruskal   race      3  0.1729  0.9818
# ACT + HRV + RRV    LSTM      accuracy Kruskal   race      3  0.0973  0.9922
# <font size="3"><b> Post-Hoc Analysis </b></font>
# **Pairwise Tests**
#                                         Contrast              A         B  \
# modality           algorithm metric
# ACT                LSTM      accuracy 0     race  Afro-american     Asian
#                                       1     race  Afro-american  Hispanic
#                                       2     race  Afro-american     White
#                                       3     race          Asian  Hispanic
#                                       4     race          Asian     White
#                                       5     race       Hispanic     White
# ACT + HRV          LSTM      accuracy 0     race  Afro-american     Asian
#                                       1     race  Afro-american  Hispanic
#                                       2     race  Afro-american     White
#                                       3     race          Asian  Hispanic
#                                       4     race          Asian     White
#                                       5     race       Hispanic     White
# ACT + HRV + ED-RRV LSTM      accuracy 0     race  Afro-american     Asian
#                                       1     race  Afro-american  Hispanic
#                                       2     race  Afro-american     White
#                                       3     race          Asian  Hispanic
#                                       4     race          Asian     White
#                                       5     race       Hispanic     White
# ACT + HRV + RRV    LSTM      accuracy 0     race  Afro-american     Asian
#                                       1     race  Afro-american  Hispanic
#                                       2     race  Afro-american     White
#                                       3     race          Asian  Hispanic
#                                       4     race          Asian     White
#                                       5     race       Hispanic     White
#
#                                          Paired  Parametric   U-val  \
# modality           algorithm metric
# ACT                LSTM      accuracy 0   False       False   882.0
#                                       1   False       False  1816.0
#                                       2   False       False  2948.0
#                                       3   False       False   697.0
#                                       4   False       False  1105.0
#                                       5   False       False  2284.0
# ACT + HRV          LSTM      accuracy 0   False       False   755.0
#                                       1   False       False  1509.0
#                                       2   False       False  2514.0
#                                       3   False       False   679.0
#                                       4   False       False  1154.0
#                                       5   False       False  2445.0
# ACT + HRV + ED-RRV LSTM      accuracy 0   False       False   731.0
#                                       1   False       False  1493.0
#                                       2   False       False  2451.0
#                                       3   False       False   674.0
#                                       4   False       False  1152.0
#                                       5   False       False  2442.0
# ACT + HRV + RRV    LSTM      accuracy 0   False       False   720.0
#                                       1   False       False  1550.0
#                                       2   False       False  2439.0
#                                       3   False       False   723.0
#                                       4   False       False  1131.0
#                                       5   False       False  2285.0
#
#                                         alternative   p-unc  hedges  p-corr
# modality           algorithm metric
# ACT                LSTM      accuracy 0   two-sided  0.1678  0.2571     1.0
#                                       1   two-sided  0.1028  0.2857     1.0
#                                       2   two-sided  0.0559  0.2767     1.0
#                                       3   two-sided  0.9631  0.0413     1.0
#                                       4   two-sided  0.8619  0.0083     1.0
#                                       5   two-sided  0.7844 -0.0356     1.0
# ACT + HRV          LSTM      accuracy 0   two-sided  0.8946 -0.1326     1.0
#                                       1   two-sided  0.8618 -0.1155     1.0
#                                       2   two-sided  0.8895 -0.0376     1.0
#                                       3   two-sided  0.8172  0.0175     1.0
#                                       4   two-sided  0.8780  0.0987     1.0
#                                       5   two-sided  0.6855  0.0806     1.0
# ACT + HRV + ED-RRV LSTM      accuracy 0   two-sided  0.9257 -0.1607     1.0
#                                       1   two-sided  0.7884 -0.1510     1.0
#                                       2   two-sided  0.9089 -0.0999     1.0
#                                       3   two-sided  0.7776  0.0114     1.0
#                                       4   two-sided  0.8888  0.0639     1.0
#                                       5   two-sided  0.6948  0.0525     1.0
# ACT + HRV + RRV    LSTM      accuracy 0   two-sided  0.8405 -0.1231     1.0
#                                       1   two-sided  0.9506 -0.0043     1.0
#                                       2   two-sided  0.8702 -0.0448     1.0
#                                       3   two-sided  0.8332  0.1351     1.0
#                                       4   two-sided  1.0000  0.0851     1.0
#                                       5   two-sided  0.7877 -0.0432     1.0

# %%
fig, ax = plt.subplots(ncols=4, figsize=(35,8))

for i, modality in enumerate(modality_list):
    df_race = multi_xs(df, [algorithm], level="algorithm")
    df_race = multi_xs(df_race, [modality], level="modality")
    sns.boxplot(
        data=multi_xs(df, [metric], level="metric").reset_index(),
        x="metric",
        y="data",
        hue="race",
        ax=ax[i],
    )
    ax[i].set_title(modality)
    ax[i].legend().remove()
    ax[i].set_xlabel("")
    ax[i].set_ylabel("Accuracy [%]")


plt.legend(ncol=4, bbox_to_anchor=(-0.5, 1.17))
plt.savefig("origin_statistics.pdf", format="pdf", bbox_inches="tight")
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
